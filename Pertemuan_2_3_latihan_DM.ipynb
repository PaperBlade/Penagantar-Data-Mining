# %% [markdown]
# <a href="https://colab.research.google.com/github/PaperBlade/Penagantar-Data-Mining/blob/main/Pertemuan_2_3_latihan_DM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
dp = pd.read_csv()

# %%
data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/data-data/world_country_and_usa_states_latitude_and_longitude_values.csv')

# %%
data
# Out:
#     country_code   latitude  longitude               country usa_state_code  \
# 0             AD  42.546245   1.601554               Andorra             AK
# 1             AE  23.424076  53.847818  United Arab Emirates             AL
# 2             AF  33.939110  67.709953           Afghanistan             AR
# 3             AG  17.060816 -61.796428   Antigua and Barbuda             AZ
# 4             AI  18.220554 -63.068615              Anguilla             CA
# ..           ...        ...        ...                   ...            ...
# 240           YE  15.552727  48.516388                 Yemen            NaN
# 241           YT -12.827500  45.166244               Mayotte            NaN
# 242           ZA -30.559482  22.937506          South Africa            NaN
# 243           ZM -13.133897  27.849332                Zambia            NaN
# 244           ZW -19.015438  29.154857              Zimbabwe            NaN
#
#      usa_state_latitude  usa_state_longitude   usa_state
# ...

# %%
data.head() #menampilkan 5 data teratas
# Out:
#   country_code   latitude  longitude               country usa_state_code  \
# 0           AD  42.546245   1.601554               Andorra             AK
# 1           AE  23.424076  53.847818  United Arab Emirates             AL
# 2           AF  33.939110  67.709953           Afghanistan             AR
# 3           AG  17.060816 -61.796428   Antigua and Barbuda             AZ
# 4           AI  18.220554 -63.068615              Anguilla             CA
#
#    usa_state_latitude  usa_state_longitude   usa_state
# 0           63.588753          -154.493062      Alaska
# 1           32.318231           -86.902298     Alabama
# 2           35.201050           -91.831833    Arkansas
# 3           34.048928          -111.093731     Arizona
# 4           36.778261          -119.417932  California

# %%
data.tail()
# Out:
#     country_code   latitude  longitude       country usa_state_code  \
# 240           YE  15.552727  48.516388         Yemen            NaN
# 241           YT -12.827500  45.166244       Mayotte            NaN
# 242           ZA -30.559482  22.937506  South Africa            NaN
# 243           ZM -13.133897  27.849332        Zambia            NaN
# 244           ZW -19.015438  29.154857      Zimbabwe            NaN
#
#      usa_state_latitude  usa_state_longitude usa_state
# 240                 NaN                  NaN       NaN
# 241                 NaN                  NaN       NaN
# 242                 NaN                  NaN       NaN
# 243                 NaN                  NaN       NaN
# 244                 NaN                  NaN       NaN

# %%
dt=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/data-data/world_country_and_usa_states_latitude_and_longitude_values.csv')

# %%
dt
# Out:
#     country_code   latitude  longitude               country usa_state_code  \
# 0             AD  42.546245   1.601554               Andorra             AK
# 1             AE  23.424076  53.847818  United Arab Emirates             AL
# 2             AF  33.939110  67.709953           Afghanistan             AR
# 3             AG  17.060816 -61.796428   Antigua and Barbuda             AZ
# 4             AI  18.220554 -63.068615              Anguilla             CA
# ..           ...        ...        ...                   ...            ...
# 240           YE  15.552727  48.516388                 Yemen            NaN
# 241           YT -12.827500  45.166244               Mayotte            NaN
# 242           ZA -30.559482  22.937506          South Africa            NaN
# 243           ZM -13.133897  27.849332                Zambia            NaN
# 244           ZW -19.015438  29.154857              Zimbabwe            NaN
#
#      usa_state_latitude  usa_state_longitude   usa_state
# ...

# %%
data.describe() #deksripsi data
# Out:
#          latitude   longitude  usa_state_latitude  usa_state_longitude
# count  244.000000  244.000000           52.000000            52.000000
# mean    16.253109   13.294814           39.153437           -92.824719
# std     27.031206   73.976477            6.967697            19.431647
# min    -75.250973 -177.156097           18.220833          -155.665857
# 25%     -0.301710  -38.092008           35.438381          -102.009600
# 50%     16.869235   18.182149           39.435516           -89.093198
# 75%     38.965238   49.046734           43.220246           -78.291302
# max     77.553604  179.414413           63.588753           -66.590149

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 245 entries, 0 to 244
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   country_code         244 non-null    object
#  1   latitude             244 non-null    float64
#  2   longitude            244 non-null    float64
#  3   country              245 non-null    object
#  4   usa_state_code       52 non-null     object
#  5   usa_state_latitude   52 non-null     float64
#  6   usa_state_longitude  52 non-null     float64
#  7   usa_state            52 non-null     object
# dtypes: float64(4), object(4)
# memory usage: 15.4+ KB

# %%
data.iloc[92]
# Out:
# country_code                   HK
# latitude                22.396428
# longitude              114.109497
# country                 Hong Kong
# usa_state_code                NaN
# usa_state_latitude            NaN
# usa_state_longitude           NaN
# usa_state                     NaN
# Name: 92, dtype: object

# %%
data["country_code"].value_counts()
# Out:
# AD    1
# MX    1
# MZ    1
# NC    1
# NE    1
#      ..
# GR    1
# GS    1
# GT    1
# GU    1
# ZW    1
# Name: country_code, Length: 244, dtype: int64

# %%
data.dtypes
# Out:
# country_code            object
# latitude               float64
# longitude              float64
# country                 object
# usa_state_code          object
# usa_state_latitude     float64
# usa_state_longitude    float64
# usa_state               object
# dtype: object

# %%
data["country"] = data["country"].astype("str")

# %%
data.dtypes
# Out:
# country_code            object
# latitude               float64
# longitude              float64
# country                 object
# usa_state_code          object
# usa_state_latitude     float64
# usa_state_longitude    float64
# usa_state               object
# dtype: object

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-470adc20-5ecc-497a-b180-359c1ae76022" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-470adc20-5ecc-497a-b180-359c1ae76022">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
dt=pd.read_excel('/content/tes.xlsx')

# %%
dt
# Out:
#      #         NIM                     Nama Mahasiswa
# 0    1  H081201039  RICHMOND ALAN CHRISTIAN TENGRIANO
# 1    2  H081211001          MAULANA RAJI SHOFIL FUADI
# 2    3  H081211002            PUTRI EKA MAHARANI ARAS
# 3    4  H081211011           ANDI ANANDA WIRDRA SISTA
# 4    5  H081211012                 MUH. RAFLI LAMBOGO
# 5    6  H081211018            APRILIA KEZIA MASSANGKA
# 6    7  H081211021        HUSNUL FAUSIAH MAGISTRAWATI
# 7    8  H081211022                     EKA INDIRAWATI
# 8    9  H081211024             WINDA ANGRAINI MARINNA
# 9   10  H081211025               LATIFAH AINUN SABINA
# 10  11  H081211026                ANANDA CAHYA KAMILA
# 11  12  H081211027                   AFIQ ATSAL ADAMI
# 12  13  H081211028                      MUH. ZULFIKAR
# 13  14  H081211029       AGATHA PASKALINE PATINTINGAN
# 14  15  H081211032            NURUL ANDIEN APRILIANTI
# 15  16  H081211033                   ANISA DWIYANTI S
# ...

# %%
dt.describe()
# Out:
#               #
# count  33.00000
# mean   17.00000
# std     9.66954
# min     1.00000
# 25%     9.00000
# 50%    17.00000
# 75%    25.00000
# max    33.00000

# %%
dt.dtypes
# Out:
# #                  int64
# NIM               object
# Nama Mahasiswa    object
# dtype: object

# %%
ap=pd.read_csv('https://storage.googleapis.com/dqlab-dataset/shopping_data_missingvalue.csv')

# %%
ap
# Out:
#      CustomerID   Genre   Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male  19.0                15.0                    39.0
# 1             2    Male   NaN                15.0                    81.0
# 2             3  Female  20.0                 NaN                     6.0
# 3             4  Female  23.0                16.0                    77.0
# 4             5  Female  31.0                17.0                     NaN
# ..          ...     ...   ...                 ...                     ...
# 195         196  Female  35.0               120.0                    79.0
# 196         197  Female  45.0               126.0                    28.0
# 197         198    Male  32.0               126.0                    74.0
# 198         199    Male  32.0               137.0                    18.0
# 199         200    Male  30.0               137.0                    83.0
#
# [200 rows x 5 columns]

# %%
ap.describe()
# Out:
#        CustomerID         Age  Annual Income (k$)  Spending Score (1-100)
# count  200.000000  199.000000          198.000000              198.000000
# mean   100.500000   38.939698           61.005051               50.489899
# std     57.879185   13.946376           26.017857               25.723587
# min      1.000000   18.000000           15.000000                1.000000
# 25%     50.750000   29.000000           42.250000               35.000000
# 50%    100.500000   36.000000           62.000000               50.000000
# 75%    150.250000   49.000000           78.000000               73.000000
# max    200.000000   70.000000          137.000000               99.000000

# %%
ap.iloc[100:110]
# Out:
#      CustomerID   Genre   Age  Annual Income (k$)  Spending Score (1-100)
# 100         101  Female  23.0                62.0                    41.0
# 101         102  Female  49.0                62.0                    48.0
# 102         103    Male  67.0                62.0                    59.0
# 103         104    Male  26.0                62.0                    55.0
# 104         105    Male  49.0                62.0                    56.0
# 105         106  Female  21.0                62.0                    42.0
# 106         107  Female  66.0                63.0                    50.0
# 107         108    Male  54.0                63.0                    46.0
# 108         109    Male  68.0                63.0                    43.0
# 109         110    Male  66.0                63.0                    48.0

# %%
sns.displot(ap['Genre'])

# %%
sns.pairplot(ap)

# %%
data.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 240    False
# 241    False
# 242    False
# 243    False
# 244    False
# Length: 245, dtype: bool

# %%
alamat = data.groupby('country_code')
alamat.count()
# Out:
#               latitude  longitude  country  usa_state_code  \
# country_code
# AD                   1          1        1               1
# AE                   1          1        1               1
# AF                   1          1        1               1
# AG                   1          1        1               1
# AI                   1          1        1               1
# ...                ...        ...      ...             ...
# YE                   1          1        1               0
# YT                   1          1        1               0
# ZA                   1          1        1               0
# ZM                   1          1        1               0
# ZW                   1          1        1               0
#
#               usa_state_latitude  usa_state_longitude  usa_state
# country_code
# AD                             1                    1          1
# AE                             1                    1          1
# ...

# %% [markdown]
# https://github.com/Mugdha-Hazra/Machine-Learning/blob/main/05.PANDAS%20LIBRARY%20and%20SEABORN%20LIBRARY.ipynb

# %%
latihan=pd.read_csv('/content/drive/MyDrive/ML DM/Mk.-Data-Mining-2021-main/Mk.-Data-Mining-2021-main/sumber data/Customer.csv')

# %%
latihan
# Out:
#     Customer ID      Customer Name      Segment  Age        Country  \
# 0      CG-12520        Claire Gute     Consumer   67  United States
# 1      DV-13045    Darrin Van Huff    Corporate   31  United States
# 2      SO-20335     Sean O'Donnell     Consumer   65  United States
# 3      BH-11710    Brosina Hoffman     Consumer   20  United States
# 4      AA-10480       Andrew Allen     Consumer   50  United States
# ..          ...                ...          ...  ...            ...
# 788    CJ-11875       Carl Jackson    Corporate   64  United States
# 789    RS-19870         Roy Skaria  Home Office   39  United States
# 790    SC-20845         Sung Chung     Consumer   69  United States
# 791    RE-19405    Ricardo Emerson     Consumer   35  United States
# 792    SM-20905  Susan MacKendrick     Consumer   46  United States
#
#                   City           State  Postal Code   Region
# 0            Henderson        Kentucky        42420    South
# ...

# %%
latihan1=pd.read_csv('/content/drive/MyDrive/ML DM/Mk.-Data-Mining-2021-main/Mk.-Data-Mining-2021-main/sumber data/Customer.csv',header=0,index_col=0)

# %%
latihan1.head()
# Out:
#                Customer Name    Segment  Age        Country             City  \
# Customer ID
# CG-12520         Claire Gute   Consumer   67  United States        Henderson
# DV-13045     Darrin Van Huff  Corporate   31  United States      Los Angeles
# SO-20335      Sean O'Donnell   Consumer   65  United States  Fort Lauderdale
# BH-11710     Brosina Hoffman   Consumer   20  United States      Los Angeles
# AA-10480        Andrew Allen   Consumer   50  United States          Concord
#
#                       State  Postal Code Region
# Customer ID
# CG-12520           Kentucky        42420  South
# DV-13045         California        90036   West
# SO-20335            Florida        33311  South
# BH-11710         California        90032   West
# AA-10480     North Carolina        28027  South

# %%
latihan1.describe()
# Out:
#               Age   Postal Code
# count  793.000000    793.000000
# mean    44.467844  55229.717528
# std     15.526673  31679.223816
# min     18.000000   1841.000000
# 25%     31.000000  27217.000000
# 50%     45.000000  55901.000000
# 75%     58.000000  90004.000000
# max     70.000000  99207.000000

# %%
alamat = latihan1.groupby('Age')
alamat.count()
# Out:
#      Customer Name  Segment  Country  City  State  Postal Code  Region
# Age
# 18              16       16       16    16     16           16      16
# 19              16       16       16    16     16           16      16
# 20              17       17       17    17     17           17      17
# 21              17       17       17    17     17           17      17
# 22              19       19       19    19     19           19      19
# 23               9        9        9     9      9            9       9
# 24              10       10       10    10     10           10      10
# 25              18       18       18    18     18           18      18
# 26              11       11       11    11     11           11      11
# 27              11       11       11    11     11           11      11
# 28              10       10       10    10     10           10      10
# 29              11       11       11    11     11           11      11
# ...

# %%
latihan1['Region'].hist()
# Out:
# <AxesSubplot:>

# %%
latihan1['Age'].hist()
# Out:
# <AxesSubplot:>

# %%
import seaborn as sns

# %%
sns.displot(latihan1.Age)

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(latihan1['Region'],latihan1['Age'])

# %%
sns.scatterplot(latihan1['Region'],latihan1['Age'])
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Region', ylabel='Age'>

# %%
sns.pairplot(latihan1)
